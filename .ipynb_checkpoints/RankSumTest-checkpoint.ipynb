# %% [markdown]
# ## Rank sum test

# %%
''' Dependencies '''
from sklearn.decomposition import PCA
from tqdm.auto import tqdm
import warnings
import pandas as pd
import numpy as np
import scipy
import sys
import statsmodels.api as sm
from tqdm import tqdm as pbar

# my scripts
from pyaldata import * 
import preprocess
from utils import *

# Plotting
from IPython.display import display, set_matplotlib_formats, HTML
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import matplotlib.colors
import matplotlib.pyplot as plt
import seaborn as sns

cs = ['#43D789', '#801607', '#8DB8ED', '#94B0B6', '#e42c12', '#005CA8', '#127340', '#111851'] # Line colors
cmap = matplotlib.colors.ListedColormap(['#ff9c8d', '#dafce3']) # Color for False and True

sns.set(rc={'figure.figsize':(10, 5)})
sns.set_style('ticks', rc={ 'figure.facecolor': 'none', 'axes.facecolor':'none'})
sns.set_context('notebook', rc={'lines.linewidth':1.5})

# %config InlineBackend.figure_format = 'retina'
# Out:
# /Users/Daphne/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
''' Load dictionaries '''

main_dict = np.load('/Users/Daphne/Data/main_dict.npy', allow_pickle='TRUE').item()
evar_to_pcs = np.load('evar_to_pcs.npy') # Convert vare to dims

''' Experimental sessions and electrode maps '''
m1_emap  = localize_elecs(read_cmp(file_path='/Users/Daphne/Data/Chewie Left M1 SN 6250-001474.cmp'),  elecs=range(1,97))
pmd_emap = localize_elecs(read_cmp(file_path='/Users/Daphne/Data/Chewie Left PMd SN 6251-001469.cmp'), elecs=range(1,97))

# %%
''' Parameters '''

MONKEY_C = 8
MONKEY_M = 7
OTHER_ARRAY_D = 50
THRESHOLDS_VARE = np.round(np.arange(0.2, 0.95, 0.025), 3)
total_n_sessions = [main_dict[s]['pcs'].shape[0] for s in main_dict.keys()]
dims_normalized = [evar_to_pcs[i, :] / total_n_sessions[i] for i in range(len(total_n_sessions))]

# %% [markdown]
# ### Non parametric rank sum test

# %%
main_dict.keys()
# Out:
# dict_keys(['2016-09-09', '2016-09-12', '2016-09-14', '2016-10-06', '2016-09-15', '2016-09-21', '2016-10-05', '2016-10-07', '2014-03-04', '2014-03-06', '2014-02-03', '2014-02-17', '2014-02-18', '2014-03-07', '2014-03-03'])

# %%
#s = '2016-09-09'

rhos_SE_all = []
rhos_SA_all = []
rhos_OA_all = []

exp_var_level = 0.3

# %%
for i, s in enumerate(main_dict.keys()):
    
    if i > MONKEY_C: break
    
    model = main_dict[s]['model']
    pcs = main_dict[s]['pcs']
    td = main_dict[s]['df']

    # Check number of PCs required to explain fraction r of the variance
    K = np.argmax(model.explained_variance_ratio_.cumsum() > exp_var_level)

    # Select factors
    L = pcs[:, :K]

    # Compute correlations
    Rho, PD, A, Idx = compute_stat_and_phys_distances(L, td['M1_unit_guide'][0], td['PMd_unit_guide'][0], m1_emap, pmd_emap, OTHER_ARRAY_D=50)

    # Convert to dataframe
    df = pd.DataFrame(data={'correlation': Rho, 'distance': PD, 'on array': A})
    df['category'] = df['distance'].apply(lambda d: 'same electrode' if d == 0 else ('same region' if d < OTHER_ARRAY_D else ('other region')))
    df['within distance'] = pd.cut(df['distance'], bins=[-0.1, 0.001, 2.01, 4.01, OTHER_ARRAY_D], labels=['0', '(0, 2]','(2, 4]', '(4, inf)'])
    df['Type'] = 'Actual'

    # make groups
    SE_rhos = df.loc[df['category'] == 'same electrode']['correlation'].values
    SA_rhos = df.loc[df['category'] == 'same region']['correlation'].values
    OA_rhos = df.loc[df['category'] == 'other region']['correlation'].values
    
    rhos_SE_all.append(SE_rhos)
    rhos_SA_all.append(SA_rhos)
    rhos_OA_all.append(OA_rhos)

# %%
# Flatten
rhos_SE_all = [item for sublist in rhos_SE_all for item in sublist]
rhos_SA_all = [item for sublist in rhos_SA_all for item in sublist]
rhos_OA_all = [item for sublist in rhos_OA_all for item in sublist]

# %%
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=['g', 'b', 'r'])
sns.set_style('ticks', rc={ 'figure.facecolor': 'none', 'axes.facecolor':'none'})
sns.set_context('notebook', rc={'lines.linewidth':1.5})

# %%
len(rhos_SE_all), len(rhos_SA_all), len(rhos_OA_all)
# Out:
# (2067, 163359, 109827)

# %%
df1 = pd.DataFrame({'correlation': np.abs(rhos_SE_all)})
df1['category'] = 'same electrode'

df2 = pd.DataFrame({'correlation': np.abs(rhos_SA_all)})
df2['category'] = 'same region'

df3 = pd.DataFrame({'correlation': np.abs(rhos_OA_all)})
df3['category'] = 'other region'

df_all = pd.concat([df1, df2, df3])

# %%
sns.violinplot(y='correlation', x='category', order=['same electrode', 'same region', 'other region'], data=df_all, saturation=0.8);

plt.title('Monkey C' , loc='left')
plt.ylabel(r'$\rho$')
plt.xlabel('')
sns.despine()

# %%
len(rhos_SE_all), len(rhos_SA_all), len(rhos_OA_all)
# Out:
# (2067, 163359, 109827)

# %%
sns.kdeplot(rhos_SE_all, alpha=0.2, label='same electrode', shade=True)
sns.kdeplot(rhos_SA_all, alpha=0.2, label='same region', shade=True)
sns.kdeplot(rhos_OA_all, alpha=0.2, label='other region', shade=True)

plt.title('Correlation distributions normalized by # obervations within groups | Monkey C' )
plt.legend(fontsize=13, loc=2)
plt.xlabel(r'$\rho$')
sns.despine()

# %%
df.head()
# Out:
#    correlation  distance on array     category within distance    Type
# 0     0.785554  1.000000       M1  same region          (0, 2]  Actual
# 1     0.943462  5.099020       M1  same region        (4, inf)  Actual
# 2     0.986348  5.099020       M1  same region        (4, inf)  Actual
# 3     0.840190  1.414214       M1  same region          (0, 2]  Actual
# 4    -0.739861  1.414214       M1  same region          (0, 2]  Actual

# %%
sns.violinplot(y='correlation', x='category', order=['same electrode', 'same region', 'other region'], data=df, saturation=0.8);

plt.title('Monkey C' , loc='left')
plt.ylabel(r'$\rho$')
plt.xlabel('')

sns.despine()

# %%
scipy.stats.ranksums(SE_rhos, SA_rhos, alternative='two-sided')
# Out:
# RanksumsResult(statistic=3.890536635762697, pvalue=0.00010002277353020307)

# %%
scipy.stats.ranksums(SA_rhos, OA_rhos, 'two-sided')
# Out:
# RanksumsResult(statistic=16.140731046116095, pvalue=1.3196894697199235e-58)

# %%
scipy.stats.ranksums(SE_rhos, OA_rhos, 'two-sided')
# Out:
# RanksumsResult(statistic=5.941619805771158, pvalue=2.8221936270943296e-09)

# %% [markdown]
# ### Less than

# %%
scipy.stats.ranksums(SE_rhos, SA_rhos, 'less')
# Out:
# RanksumsResult(statistic=3.7456871918585715, pvalue=0.9999100496784973)

# %%
scipy.stats.ranksums(SE_rhos, OA_rhos, 'less')
# Out:
# RanksumsResult(statistic=5.917123054171814, pvalue=0.9999999983618921)

# %%
scipy.stats.ranksums(SA_rhos, OA_rhos, 'less')
# Out:
# RanksumsResult(statistic=13.615588679473609, pvalue=1.0)

# %% [markdown]
# ### Greater than

# %%
scipy.stats.ranksums(SE_rhos, SA_rhos, 'greater')
# Out:
# RanksumsResult(statistic=3.7456871918585715, pvalue=8.995032150275171e-05)

# %%
scipy.stats.ranksums(SE_rhos, OA_rhos, 'greater')
# Out:
# RanksumsResult(statistic=5.917123054171814, pvalue=1.6381079194658093e-09)

# %%
scipy.stats.ranksums(SA_rhos, OA_rhos, 'greater')
# Out:
# RanksumsResult(statistic=13.615588679473609, pvalue=1.6176413686418417e-42)
